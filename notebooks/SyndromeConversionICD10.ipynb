# %%
import csv
import pandas as pd

# %%
from IPython.display import display

# %%
GEMS_ICD9_COL = 'GemsICD9'
GEMS_ICD10_COL = 'GemsICD10'
GEMS_ICD9_TO_ICD10_FLAG = 'GemsICD9_to_ICD10_Flag'
def read_icd9_to_icd10_file(filename):
    file = open(filename, 'r')
    
    rows = []
    
    for line in file:
        tokens = line.split()
        mapping_row = {GEMS_ICD9_COL : tokens[0],
                      GEMS_ICD10_COL : tokens[1],
                      GEMS_ICD9_TO_ICD10_FLAG : tokens[2]}
        rows.append(mapping_row)
        
    mapping_df = pd.DataFrame(rows)
    
    file.close()
    
    return mapping_df

# %%
icd9_to_icd10_df = read_icd9_to_icd10_file('../data/gems/2017_I9gem.txt')
display(icd9_to_icd10_df)
# Out:
#       GemsICD10 GemsICD9 GemsICD9_to_ICD10_Flag
# 0          A000     0010                  00000
# 1          A001     0011                  00000
# 2          A009     0019                  00000
# 3         A0100     0020                  10000
# 4          A011     0021                  00000
# 5          A012     0022                  00000
# 6          A013     0023                  00000
# 7          A014     0029                  00000
# 8          A020     0030                  00000
# 9          A021     0031                  10000
# 10        A0220    00320                  00000
# 11        A0221    00321                  00000
# 12        A0222    00322                  00000
# 13        A0223    00323                  00000
# 14        A0224    00324                  00000
# 15        A0229    00329                  10000
# 16         A028     0038                  00000
# 17         A029     0039                  00000
# 18         A030     0040                  00000
# 19         A031     0041                  00000
# 20         A032     0042                  00000
# 21         A033     0043                  00000
# 22         A038     0048                  00000
# 23         A039     0049                  00000
# 24         A050     0050                  00000
# 25         A051     0051                  00000
# 26         A052     0052                  00000
# 27         A058     0053                  10000
# 28         A053     0054                  00000
# 29         A055    00581                  00000
# ...         ...      ...                    ...
# 24660     Z1809    V9009                  00000
# 24661     Z1810    V9010                  00000
# 24662     Z1811    V9011                  00000
# 24663     Z1812    V9012                  00000
# 24664      Z182     V902                  00000
# 24665     Z1831    V9031                  00000
# 24666     Z1832    V9032                  00000
# 24667     Z1833    V9033                  00000
# 24668     Z1839    V9039                  00000
# 24669     Z1881    V9081                  00000
# 24670     Z1883    V9083                  00000
# 24671     Z1889    V9089                  00000
# 24672      Z189     V909                  00000
# 24673    O30009    V9100                  10000
# 24674    O30019    V9101                  10000
# 24675    O30039    V9102                  10000
# 24676    O30049    V9103                  10000
# 24677    O30099    V9109                  10000
# 24678    O30109    V9110                  10000
# 24679    O30119    V9111                  10000
# 24680    O30129    V9112                  10000
# 24681    O30199    V9119                  10000
# 24682    O30209    V9120                  10000
# 24683    O30219    V9121                  10000
# 24684    O30229    V9122                  10000
# 24685    O30299    V9129                  10000
# 24686    O30809    V9190                  10000
# 24687    O30819    V9191                  10000
# 24688    O30829    V9192                  10000
# 24689    O30899    V9199                  10000
#
# [24690 rows x 3 columns]

# %%
syndrome_sheet_map = pd.read_excel('../data/icd9_surveillance/syndromedefinitions_combined.xlsx', sheetname = None)
print('Read total sheets from Surveillance Excel file : {0}'.format(len(syndrome_sheet_map)))
# Out:
# Read total sheets from Surveillance Excel file : 11

# %%
# we want to keep the sheetnames, so let's add them to each dataframe now...
SYNDROME_CATEGORY_COL = 'Category'
sheet_df_list = []
for sheet in syndrome_sheet_map.keys():
    sheet_df = syndrome_sheet_map[sheet]
    sheet_df[SYNDROME_CATEGORY_COL] = sheet
    sheet_df_list.append(sheet_df)
    print(sheet)
# Out:
# Fever
# Rash
# Gastrointestinal Upper
# Hemorrhagic Illness
# Neurological
# Botulism-like
# Sudden Death or Illness
# Lymphadenitis
# Respiratory
# Lesion
# Gastrointestinal Lower

# %%
# now let's combine the category sheets into a combined frame
syndrome_combined_df = pd.concat(sheet_df_list)
print('Total combined ICD9 surveillance codes : {0}'.format(len(syndrome_combined_df)))
# Out:
# Total combined ICD9 surveillance codes : 726

# %%
# let's convert the ICD9 codes from floats to strings
syndrome_combined_df['ICD9CM\n'] = syndrome_combined_df['ICD9CM\n'].astype(str)

# %%
display(syndrome_combined_df)
# Out:
#     ICD9CM\n                                        ICD9DESCR\n  Consensus\n  \
# 0       20.2                               PLAGUE, SEPTICEMIC\n          1.0
# 1       20.8                            OTHER TYPES OF PLAGUE\n          1.0
# 2       20.9                                       PLAGUE NOS\n          1.0
# 3       21.8                                    TULAREMIA NEC\n          1.0
# 4       21.9                                    TULAREMIA NOS\n          1.0
# 5       22.3                              ANTHRAX, SEPTICEMIA\n          1.0
# 6       22.8                         ANTHRAX, OTHER SPECIFIED\n          1.0
# 7       22.9                             ANTHRAX, UNSPECIFIED\n          1.0
# 8       38.3                             ANAEROBES SEPTICEMIA\n          1.0
# 9       38.4                        GRAM-NEGATIVE ORGANISM UN\n          1.0
# 10     38.49                        SEPTICEMIA,OTHER GRAM-NEG\n          1.0
# 11      38.8                        SEPTICEMIAS, OTHER SPECIF\n          1.0
# 12      38.9                                  SEPTICEMIA, NOS\n          1.0
# 13     79.89                          VIRAL INFECTION OTHER S\n          1.0
# 14     79.99                     VIRAL INFECTIONS UNSPECIFIED\n          1.0
# 15    780.31                              FEBRILE CONVULSIONS\n          1.0
# 16     780.6                                            FEVER\n          1.0
# 17     790.7                                       BACTEREMIA\n          1.0
# 18     790.8                                      VIREMIA NOS\n          1.0
# 19       nan                                                NaN          NaN
# 20       2.0                                    TYPHOID FEVER\n          3.0
# 21       2.1                              PARATYPHOID FEVER A\n          3.0
# 22       2.2                              PARATYPHOID FEVER B\n          3.0
# 23       2.3                              PARATYPHOID FEVER C\n          3.0
# 24       2.9                            PARATYPHOID FEVER NOS\n          3.0
# 25       3.1                            Salmonella septicemia\n          3.0
# 26      23.0                              BRUCELLA MELITENSIS\n          3.0
# 27      23.1                                 BRUCELLA ABORTUS\n          3.0
# 28      23.2                                    BRUCELLA SUIS\n          3.0
# 29      23.3                                   BRUCELLA CANIS\n          3.0
# ..       ...                                                ...          ...
# 80       8.1                                ARIZONA ENTERITIS\n          3.0
# 81       8.2                             AEROBACTER ENTERITIS\n          3.0
# 82       8.3                                PROTEUS ENTERITIS\n          3.0
# 83      8.41                           STAPHYLOCOCC ENTERITIS\n          3.0
# 84      8.43                          CAMPYLOBACTER ENTERITIS\n          3.0
# 85      8.44                          YERSINIA ENTEROCOLITICA\n          3.0
# 86      8.45                            CLOSTRIDIUM DIFFICILE\n          3.0
# 87      8.46                        INTESTINAL INF.DUE TO ANA\n          3.0
# 88      8.47                           GRAM-NEG ENTERITIS NEC\n          3.0
# 89      8.61                          ENTERITIS D/T ROTAVIRUS\n          3.0
# 90      8.62                         ENTERITIS D/T ADENOVIRUS\n          3.0
# 91      8.63                      ENTERITIS D/T NORWALK VIRUS\n          3.0
# 92      8.64              ENTERITIS D/T SMALL ROUND VIRUS NEC\n          3.0
# 93      8.65                         ENTERITIS D/T CALCIVIRUS\n          3.0
# 94      8.66                         ENTERITIS D/T ASTROVIRUS\n          3.0
# 95      8.67  ENTERITIS DUE TO ENTEROVIRUS NOT\nELSEWHERE CL...          3.0
# 96      21.1                               TULAREMIA, ENTERIC\n          3.0
# 97     127.0                                       ASCARIASIS\n          3.0
# 98     127.1                                      ANISAKIASIS\n          3.0
# 99     127.2                                 STRONGYLOIDIASIS\n          3.0
# 100    127.3                                     TRICHURIASIS\n          3.0
# 101    127.4                                     ENTEROBIASIS\n          3.0
# 102    127.5                                    CAPILLARIASIS\n          3.0
# 103    127.6                              TRICHOSTRONGYLIASIS\n          3.0
# 104    127.7                         INTEST HELMINTHIASIS NEC\n          3.0
# 105    127.8                         MIXED INTESTINE HELMINTH\n          3.0
# 106    127.9                        INTESTINAL HELMINTHIASIS,\n          3.0
# 107    129.0                        INTESTINAL PARASITISM UNS\n          3.0
# 108    567.0                         PERITONITIS IN INFEC DIS\n          3.0
# 109    787.4                             PERISTALSIS, VISIBLE\n          3.0
#
#                    Category
# 0                     Fever
# 1                     Fever
# 2                     Fever
# 3                     Fever
# 4                     Fever
# 5                     Fever
# 6                     Fever
# 7                     Fever
# 8                     Fever
# 9                     Fever
# 10                    Fever
# 11                    Fever
# 12                    Fever
# 13                    Fever
# 14                    Fever
# 15                    Fever
# 16                    Fever
# 17                    Fever
# 18                    Fever
# 19                    Fever
# 20                    Fever
# 21                    Fever
# 22                    Fever
# 23                    Fever
# 24                    Fever
# 25                    Fever
# 26                    Fever
# 27                    Fever
# 28                    Fever
# 29                    Fever
# ..                      ...
# 80   Gastrointestinal Lower
# 81   Gastrointestinal Lower
# 82   Gastrointestinal Lower
# 83   Gastrointestinal Lower
# 84   Gastrointestinal Lower
# 85   Gastrointestinal Lower
# 86   Gastrointestinal Lower
# 87   Gastrointestinal Lower
# 88   Gastrointestinal Lower
# 89   Gastrointestinal Lower
# 90   Gastrointestinal Lower
# 91   Gastrointestinal Lower
# 92   Gastrointestinal Lower
# 93   Gastrointestinal Lower
# 94   Gastrointestinal Lower
# 95   Gastrointestinal Lower
# 96   Gastrointestinal Lower
# 97   Gastrointestinal Lower
# 98   Gastrointestinal Lower
# 99   Gastrointestinal Lower
# 100  Gastrointestinal Lower
# 101  Gastrointestinal Lower
# 102  Gastrointestinal Lower
# 103  Gastrointestinal Lower
# 104  Gastrointestinal Lower
# 105  Gastrointestinal Lower
# 106  Gastrointestinal Lower
# 107  Gastrointestinal Lower
# 108  Gastrointestinal Lower
# 109  Gastrointestinal Lower
#
# [726 rows x 4 columns]

# %%
def get_icd10_converted_codes(icd9_syndrome_df, icd9_gems_df):
    icd10_rows = []
    # now let's cycle through and get all codes mapped from ICD9 to ICD10
    for index, row in syndrome_combined_df.iterrows():
        #print(row.Index)
        #print(row)
        icd9_original_key = row['ICD9CM\n']
        
        if len(icd9_original_key) <= 0 or 'nan' in icd9_original_key:
            print('Skipping row with an empty key...')
        #print(icd9_original_key)
        
        # in order to look this up in the GEMS frame, we need to set up the ICD9 key the right way
        icd9_parts = icd9_original_key.split('.')
        left_part = icd9_parts[0]
        
        # default to 0 in case there is no explicit part right of the decimal point
        right_part = '0'
        if len(icd9_parts) > 1:
            right_part = icd9_parts[1]
            
        if len(left_part) == 1:
            left_part = '00' + left_part
        elif len(left_part) == 2:
            left_part = '0' + left_part
            
        # now let's put together a key that we can use for lookups in the GEMS mappingrows
        icd9_gems_key = left_part + right_part
        icd10_matched_rows = icd9_gems_df[icd9_gems_df[GEMS_ICD9_COL] == icd9_gems_key]
        if len(icd10_matched_rows) == 0:
            print('No GEMS ICD9 matched rows for {0} ({1})'.format(icd9_gems_key, icd9_original_key))
        #print(icd10_rows)
        
    return pd.DataFrame(icd10_rows)
        
icd10_surveillance_df = get_icd10_converted_codes(syndrome_combined_df, icd9_to_icd10_df)
display(icd10_surveillance_df)
# Out:
# No GEMS ICD9 matched rows for 0384 (38.4)
# No GEMS ICD9 matched rows for 7806 (780.6)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for 0240 (24.0)
# No GEMS ICD9 matched rows for 0250 (25.0)
# No GEMS ICD9 matched rows for 0381 (38.1)
# No GEMS ICD9 matched rows for 0800 (80.0)
# No GEMS ICD9 matched rows for 10082 (100.82)
# No GEMS ICD9 matched rows for 0510 (51.0)
# No GEMS ICD9 matched rows for 6951 (695.1)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for 0532 (53.2)
# No GEMS ICD9 matched rows for 5350 (535.0)
# No GEMS ICD9 matched rows for 5354 (535.4)
# No GEMS ICD9 matched rows for 5355 (535.5)
# No GEMS ICD9 matched rows for 5356 (535.6)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for 7872 (787.2)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for 5118 (511.8)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for 2873 (287.3)
# No GEMS ICD9 matched rows for 2874 (287.4)
# No GEMS ICD9 matched rows for 7863 (786.3)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for 0610 (61.0)
# No GEMS ICD9 matched rows for 0480 (48.0)
# No GEMS ICD9 matched rows for 3238 (323.8)
# No GEMS ICD9 matched rows for 3483 (348.3)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for 0531 (53.1)
# No GEMS ICD9 matched rows for 0560 (56.0)
# No GEMS ICD9 matched rows for 0610 (61.0)
# No GEMS ICD9 matched rows for 0640 (64.0)
# No GEMS ICD9 matched rows for 0664 (66.4)
# No GEMS ICD9 matched rows for 0710 (71.0)
# No GEMS ICD9 matched rows for 1362 (136.2)
# No GEMS ICD9 matched rows for 3230 (323.0)
# No GEMS ICD9 matched rows for 3234 (323.4)
# No GEMS ICD9 matched rows for 3235 (323.5)
# No GEMS ICD9 matched rows for 3236 (323.6)
# No GEMS ICD9 matched rows for 3237 (323.7)
# No GEMS ICD9 matched rows for 3743 (374.3)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for 3429 (342.9)
# No GEMS ICD9 matched rows for 3440 (344.0)
# No GEMS ICD9 matched rows for 3580 (358.0)
# No GEMS ICD9 matched rows for 7845 (784.5)
# No GEMS ICD9 matched rows for 7872 (787.2)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for 0370 (37.0)
# No GEMS ICD9 matched rows for 3785 (378.5)
# No GEMS ICD9 matched rows for 7855 (785.5)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for 6564 (656.4)
# No GEMS ICD9 matched rows for 0750 (75.0)
# No GEMS ICD9 matched rows for 6830 (683.0)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for 4600 (460.0)
# No GEMS ICD9 matched rows for 4620 (462.0)
# No GEMS ICD9 matched rows for 4630 (463.0)
# No GEMS ICD9 matched rows for 4640 (464.0)
# No GEMS ICD9 matched rows for 4641 (464.1)
# No GEMS ICD9 matched rows for 4642 (464.2)
# No GEMS ICD9 matched rows for 4643 (464.3)
# No GEMS ICD9 matched rows for 4645 (464.5)
# No GEMS ICD9 matched rows for 4850 (485.0)
# No GEMS ICD9 matched rows for 4860 (486.0)
# No GEMS ICD9 matched rows for 4900 (490.0)
# No GEMS ICD9 matched rows for 5118 (511.8)
# No GEMS ICD9 matched rows for 7690 (769.0)
# No GEMS ICD9 matched rows for 7860 (786.0)
# No GEMS ICD9 matched rows for 7863 (786.3)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for 0750 (75.0)
# No GEMS ICD9 matched rows for 3810 (381.0)
# No GEMS ICD9 matched rows for 3815 (381.5)
# No GEMS ICD9 matched rows for 3820 (382.0)
# No GEMS ICD9 matched rows for 3820 (382.0)
# No GEMS ICD9 matched rows for 3820 (382.0)
# No GEMS ICD9 matched rows for 4930 (493.0)
# No GEMS ICD9 matched rows for 4931 (493.1)
# No GEMS ICD9 matched rows for 4939 (493.9)
# No GEMS ICD9 matched rows for 5140 (514.0)
# No GEMS ICD9 matched rows for 7865 (786.5)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for 1150 (115.0)
# No GEMS ICD9 matched rows for 1151 (115.1)
# No GEMS ICD9 matched rows for 1159 (115.9)
# No GEMS ICD9 matched rows for 4810 (481.0)
# No GEMS ICD9 matched rows for 4823 (482.3)
# No GEMS ICD9 matched rows for 4824 (482.4)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for 6810 (681)
# No GEMS ICD9 matched rows for 7071 (707.1)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for E9064
#  (E906.4
# )
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for 5672 (567.2)
# No GEMS ICD9 matched rows for 5678 (567.8)
# No GEMS ICD9 matched rows for 7890 (789.0)
# No GEMS ICD9 matched rows for 7896 (789.6)
# Skipping row with an empty key...
# No GEMS ICD9 matched rows for nan0 (nan)
# No GEMS ICD9 matched rows for 0032 (3.2)
# No GEMS ICD9 matched rows for 0080 (8.0)
# No GEMS ICD9 matched rows for 1290 (129.0)
# Empty DataFrame
# Columns: []
# Index: []
